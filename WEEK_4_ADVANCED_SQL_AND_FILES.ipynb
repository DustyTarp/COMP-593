# %% [markdown]
# <a href="https://colab.research.google.com/github/DustyTarp/COMP-593/blob/main/WEEK_4_ADVANCED_SQL_AND_FILES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 4 - Advanced SQL / Writing Files
#
# In this week's lab, we are going to expand our Really Simple Social Network by adding another table that will record connections between people! Because after all, what good is a social network if you can't ... be social?
#
# Afterwards, we will be in a good position to run a report on the data, and then we can sell it to marketers for a massive profit! Isn't it great how few people read the terms of service? `/s`

# %% [markdown]
# ## Importing our database
# Since we are using a new colab notebook, we will need to reimport our database. Check your D2L Submission if you didn't keep a copy, you should be able to redownload it there. Run the below code block and the file upload picker will appear, after uploading your Database file, check that it appears in the `Files` tab of colab.
#
# Remember that you may need to update the listings before it will appear.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-471a3010-9553-4661-986b-4d91357a12ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-471a3010-9553-4661-986b-4d91357a12ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving social_network.db to social_network.db

# %% [markdown]
# ## Creating our relationship table
#
# In the code block below, we will be creating a new table in our database for `relationships` with the following parameters:
#
#
# 1.   A primary key column called `id` with the `INTEGER` datatype that is `NOT NULL`
# 2.   A foreign key column called `user_id` that links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 3.   Another foreign key column called `friend_id` that also links to the `id` column of the `people` table with the `INTEGER` datatype that is `NOT NULL`
# 4.   A `date_created` table with the `DATE` datatype that is `NOT NULL`
#
# The Below codeblock will get you started:

# %%
import sqlite3

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#The Primary Key column has been provided for you,
#Replace '#!...' with the remaining column names, datatypes, and foreign key declarations.
#Use the Lecture notes and the previous lab if you are unsure.
createRelationshipsTable = """CREATE TABLE IF NOT EXISTS relationships (
                          id integer PRIMARY KEY NOT NULL,
                          user_id integer NOT NULL,
                          friend_id integer NOT NULL,
                          FOREIGN KEY (user_id) REFERENCES people (id),
                          FOREIGN KEY (friend_id) REFERENCES people (id)
                        );"""

#Once again, we will execute the query, persist the changes, and close our connection.
myCursor.execute(createRelationshipsTable)
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Populating Relationship Data
#
# We're not going to be picky about who knows who - so for the purposes of this lab, we're going to use our own version of an AI matchmaker, the `randrange()` method.
#
# Complete the below codeblock, inserting 1000 new rows into the relationships table.
# Use a random number between `1 - 1000` for the `user_id` and `friend_id` columns. This will link up to the `id` column of the `people` table and effectivly simulate a random network of relationships.
#
# The below code block is purposely sparse, as you should be able to use the patterns you've identified in the previous lab to complete this task.

# %%
import sqlite3
from datetime import datetime #For generating dates and times
from random import randrange #For generating random numbers within a range

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Complete the below query
query =  """INSERT INTO relationships(user_id, friend_id)
            VALUES (?, ?)"""

for _ in range(1000):
  #Populate the arguments that will be used in the query
  user_id = randrange(1, 1001)

  friend_id = user_id
  while friend_id == user_id:
    friend_id = randrange(1, 1001)

  args = (user_id, friend_id)
  #Execute the query
  myCursor.execute(query, args)

#Commit your changes and close the connection.
myConnection.commit()
myConnection.close()

# %% [markdown]
# ## Building our Report
#
# Now that our AI Matchmaker has generated our network of relationships, a marketing firm is offering us boatloads of cash for information about the amount of friends the users of our social network have.
#
# The request is to return the name of each user, and the total number of relationships they have made.
#
# If this was explained in awkward pseudo code, it might go something like this:
# ```
# SELECT all relationships
# JOIN them to the people they belong to
# GROUP the results by the person's ID
# return the person's name and COUNT of their relationships
# ```
#
# After you have collected the data, you will need to write it to a `.txt` file.
#
# **Your submission will include the report `.txt` file, the copy of your updated `social_network.db` file, and a link to the colab notebook.**
#
# Look at the aggregate functions from Week 3 and the Join examples from Week 4. There are a few different ways that you can structure a query to reach the correct answer.
#
# **At a minimum, you will need to use a `LEFT JOIN` statement, a `GROUP BY` statement, and a `COUNT()` aggregate function.**
#
# The below code block will get you started:

# %%
from os import close
import sqlite3
from pprint import pprint

#Retreive the Connection object, rename the file to match your uploaded DB if necessary.
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Complete the below query
query =  """SELECT people.name, COUNT(relationships.friend_id) FROM relationships
            LEFT JOIN people ON relationships.user_id = people.id
            GROUP BY relationships.user_id
         """

myCursor.execute(query)
results = myCursor.fetchall()
pprint(results)

myConnection.close()

#Uncomment the below line after you have determined what the correct mode will be for your file pointer.
fp = open('report.txt', mode='w')

for result in results:
  fp.write(str(result))
  fp.write('\n')
fp = close('report.txt')

#Don't forget to close the file pointer after you have finished!
# Out:
# [('John Doe', 1),
#  ('Linda Clark', 1),
#  ('Brittany Howard', 1),
#  ('Michael Larson', 2),
#  ('Ashley Stokes', 3),
#  ('Mark Moore', 3),
#  ('Tiffany Melendez', 1),
#  ('Danielle Andrews', 1),
#  ('Jennifer Morrison', 2),
#  ('Todd Reese', 2),
#  ('Sean Gonzales', 2),
#  ('Michael White', 1),
#  ('Peter Joseph', 1),
#  ('Kimberly Gilmore MD', 1),
#  ('Madison Hall', 1),
#  ('Anna Lee', 2),
#  ('Troy Clark', 2),
#  ('Dawn Anderson', 2),
#  ('Rebecca Hughes', 3),
#  ('Donald Mckenzie', 3),
#  ('Samantha Meyers', 1),
#  ('Maria Mcdaniel', 1),
#  ('Jennifer Schmidt', 1),
#  ('Kenneth Robbins', 1),
#  ('William Keller', 1),
#  ('Veronica Lawson', 1),
#  ('Morgan Franklin', 1),
#  ('Raymond Reyes', 1),
#  ('Matthew Stewart', 2),
#  ('Matthew Davis', 1),
#  ('Charles Howard', 1),
#  ('Scott Landry', 3),
#  ('Dawn Mcguire', 3),
#  ('Glenn Orr', 1),
#  ('Michael Johnson', 2),
#  ('Micheal Morgan', 2),
#  ('Stephen Hutchinson', 3),
#  ('Scott Roberts', 1),
#  ('Timothy Fox', 1),
#  ('Michael Elliott', 1),
#  ('Brandon Lawrence', 1),
#  ('Keith Weeks', 3),
#  ('Amanda Parker', 2),
#  ('Jordan Reynolds', 1),
#  ('Kevin Martin', 1),
#  ('Ronald Kelley', 1),
#  ('Andrea Gonzalez', 1),
#  ('Elizabeth Tran', 1),
#  ('Jenny Montoya', 2),
#  ('Patrick Long', 1),
#  ('Shelby Schwartz', 1),
#  ('Amanda Garcia', 1),
#  ('Crystal Butler', 1),
#  ('Michael Chapman', 3),
#  ('Jesse Moore', 1),
#  ('Hector Wood', 1),
#  ('Fernando Ward', 1),
#  ('Tina Lutz', 1),
#  ('Michael Noble', 1),
#  ('Cynthia Norris', 1),
#  ('Michelle Young', 1),
#  ('Rhonda Johnson', 2),
#  ('Jennifer Riggs', 4),
#  ('Brandy White', 1),
#  ('Austin Gibson', 1),
#  ('Darlene Rogers', 2),
#  ('Kristin Nichols', 1),
#  ('Alexandra Miller', 2),
#  ('Anna Cook', 4),
#  ('Alicia Larson MD', 1),
#  ('Samuel Mckinney', 3),
#  ('Kristina Bradley', 1),
#  ('Mr. William Lozano', 2),
#  ('Bonnie Harrison', 3),
#  ('Mrs. Katherine Bailey MD', 1),
#  ('Angela Parrish', 2),
#  ('Melissa Smith DDS', 2),
#  ('Tammy Henry', 1),
#  ('Daniel Burns', 2),
#  ('Peter Bennett', 1),
#  ('William Moore', 1),
#  ('Caitlin Kirk DDS', 2),
#  ('Lauren Martinez', 2),
#  ('Kimberly Johnson', 2),
#  ('Shaun Wilson', 2),
#  ('Gloria Lucas', 2),
#  ('Jose Klein', 2),
#  ('Tiffany Freeman', 2),
#  ('Brett Campbell', 2),
#  ('Christopher Abbott', 1),
#  ('Travis Anderson', 1),
#  ('John Stone', 1),
#  ('Lindsay Johnson', 2),
#  ('Jacob Christian', 2),
#  ('Tanner Hansen', 1),
#  ('Ethan Crawford', 2),
#  ('Laurie Petersen', 1),
#  ('Carolyn Williams', 2),
#  ('Joshua Morgan', 1),
#  ('Sarah Lee', 2),
#  ('Christopher Morris', 1),
#  ('Scott Sanders', 2),
#  ('Joseph Graham', 3),
#  ('Sarah Murphy', 3),
#  ('Mark Stephens', 1),
#  ('Shannon Garrett', 1),
#  ('Renee Wong', 1),
#  ('Brandon Brown', 1),
#  ('Dean Burke', 3),
#  ('Stephen Silva', 2),
#  ('Jose Nelson DDS', 2),
#  ('Larry Tanner', 1),
#  ('Barbara Wolfe', 2),
#  ('Alexis Anderson', 1),
#  ('Jennifer Edwards', 1),
#  ('Brandon Harrington', 1),
#  ('Monique Dyer', 1),
#  ('Cynthia Campbell', 2),
#  ('Heather Browning', 2),
#  ('Mary Bernard', 1),
#  ('Samantha Duran', 1),
#  ('Lisa Torres', 1),
#  ('Nicholas Hernandez', 1),
#  ('Catherine Price', 1),
#  ('Cindy Warren', 3),
#  ('James Howard', 1),
#  ('Edward Rodriguez', 1),
#  ('Ricardo Davis', 1),
#  ('Steven Coleman', 1),
#  ('Ashley Chapman', 1),
#  ('Catherine Huerta', 2),
#  ('Michelle Clark', 3),
#  ('George Miles', 1),
#  ('Crystal Baker', 1),
#  ('Matthew Parsons', 2),
#  ('Kelsey Greene', 1),
#  ('Anthony Ramos', 2),
#  ('Melissa Robertson', 1),
#  ('Tammy Hampton', 2),
#  ('Tom Mitchell', 1),
#  ('Robin Smith', 1),
#  ('Edwin Smith', 3),
#  ('Chris Jones', 1),
#  ('Cheryl Fry', 1),
#  ('Benjamin Ali', 1),
#  ('Rhonda Curtis', 2),
#  ('Samantha Gonzalez', 2),
#  ('Pamela Huber', 3),
#  ('Brian Holmes', 1),
#  ('Robin Lindsey', 2),
#  ('Rebecca Bush', 3),
#  ('Ricky Paul', 1),
#  ('April Berry', 2),
#  ('Kelly Leon', 2),
#  ('Elizabeth Keith', 1),
#  ('Marie Ross', 1),
#  ('Ashley Reyes', 3),
#  ('Wendy Torres', 1),
#  ('Michael Johnson', 1),
#  ('Jeffery May', 1),
#  ('Michael Brown', 1),
#  ('Kent Ford', 1),
#  ('Carol Patterson', 4),
#  ('Terrance Malone', 3),
#  ('Mary Rocha', 3),
#  ('Katherine Travis DDS', 2),
#  ('William Maldonado', 1),
#  ('Craig Ramirez', 1),
#  ('Edward Thompson', 1),
#  ('Bryan Johnson', 1),
#  ('Joe Garcia', 2),
#  ('Patricia Love', 2),
#  ('John Walters', 1),
#  ('Shelley Jones', 2),
#  ('Omar Crane', 2),
#  ('Mr. Christopher Chapman', 1),
#  ('Richard Riley', 1),
#  ('Jeffrey Parker', 2),
#  ('Melissa Reynolds', 2),
#  ('Dr. Cassandra Brewer', 1),
#  ('Dale Gibson', 1),
#  ('Rebecca Johnson', 3),
#  ('Robert Ellis', 2),
#  ('Patrick Brown', 2),
#  ('Mary Medina', 2),
#  ('Andrew Parrish', 1),
#  ('Elizabeth Yates', 1),
#  ('Steven Houston', 1),
#  ('Melissa Holmes', 1),
#  ('Michelle Hayes', 1),
#  ('Lisa Callahan', 3),
#  ('Jodi Odom', 1),
#  ('William Marshall', 1),
#  ('Mario Young', 1),
#  ('Dorothy Kidd', 1),
#  ('Sarah Carroll', 2),
#  ('Julia Hayes', 1),
#  ('Francisco Mcbride', 1),
#  ('Melissa Wallace', 1),
#  ('Jeffrey Johnston', 1),
#  ('Lisa Proctor', 2),
#  ('Lindsey Sanchez', 2),
#  ('Tanner Farmer', 1),
#  ('Matthew Mills', 1),
#  ('Bonnie Rodriguez', 2),
#  ('Daniel Prince', 2),
#  ('Randy Miller', 1),
#  ('Brett Reynolds', 1),
#  ('Amy Richardson', 1),
#  ('Wendy Jenkins', 1),
#  ('Amy Hunter', 2),
#  ('Vanessa Morton', 2),
#  ('Crystal Dean', 1),
#  ('Jacqueline Williams', 3),
#  ('Jill Patel', 1),
#  ('Robert Nguyen', 4),
#  ('Stephanie Allen', 3),
#  ('Lynn Floyd', 1),
#  ('Shawn Arias Jr.', 2),
#  ('Diane Burch', 1),
#  ('Kelly Stevens', 2),
#  ('Stefanie Perry', 2),
#  ('Jerry Luna', 1),
#  ('Danielle Carter', 1),
#  ('Jill Carroll', 1),
#  ('David Ibarra', 1),
#  ('Virginia Reynolds', 2),
#  ('Teresa Anderson', 1),
#  ('Stacy Barrett', 2),
#  ('Lindsay Hays', 2),
#  ('Joseph Conner', 2),
#  ('Jesse Mejia', 2),
#  ('Paul Rogers', 2),
#  ('Diana Wilson', 1),
#  ('Jennifer Bush', 1),
#  ('Michael Hunter', 1),
#  ('Sean Gray', 2),
#  ('Keith Miller', 1),
#  ('Joseph Sanchez', 1),
#  ('Jorge Conner', 2),
#  ('Blake Adams', 1),
#  ('Aaron Boyd', 1),
#  ('Tammy Lewis', 1),
#  ('Briana King', 1),
#  ('Joy Lane', 5),
#  ('Jeffrey Smith', 2),
#  ('Kelly Blake', 1),
#  ('Michael Hawkins', 1),
#  ('Kathryn Nelson', 1),
#  ('Cody Mcclain', 1),
#  ('Rebecca Taylor MD', 1),
#  ('Ms. Amanda Cortez DDS', 1),
#  ('Joshua Martinez', 2),
#  ('Mary Moore', 3),
#  ('Dana Vega', 1),
#  ('Dawn Cooper', 1),
#  ('Eric Oliver', 1),
#  ('Heidi Li', 1),
#  ('Pamela Johnson', 1),
#  ('Kyle Little', 1),
#  ('Katie Sanchez', 2),
#  ('Tonya Poole', 3),
#  ('Melissa Walker', 1),
#  ('Adam Smith', 2),
#  ('Brad Cole', 3),
#  ('Brandon Garcia', 1),
#  ('Elizabeth Hall', 1),
#  ('Susan Smith', 1),
#  ('Michele Young', 2),
#  ('Justin Garcia', 2),
#  ('Allen Guerra', 1),
#  ('Paul Lam', 1),
#  ('Dr. Jo Adams', 1),
#  ('Kayla Ayala', 1),
#  ('Miranda Foster', 2),
#  ('Fernando Wang', 1),
#  ('Veronica Schneider', 2),
#  ('Marissa Cook', 1),
#  ('Daisy Miller', 1),
#  ('Brenda Hess', 1),
#  ('Christopher Zuniga', 1),
#  ('Linda Patton', 3),
#  ('Audrey Jones', 3),
#  ('Kelly Weber', 1),
#  ('Kimberly Ward', 1),
#  ('Steven Lewis', 1),
#  ('Joseph Rogers', 2),
#  ('Cassandra Johnson', 3),
#  ('Sheena Bailey', 1),
#  ('Teresa Richardson', 1),
#  ('Leslie Thomas', 1),
#  ('Stephanie Dixon', 3),
#  ('Richard Castro', 3),
#  ('Nathan Miller', 1),
#  ('Gabrielle Webb DVM', 1),
#  ('Jason Edwards MD', 1),
#  ('Sara Christian', 1),
#  ('Carlos Simon', 1),
#  ('Thomas Wright DDS', 3),
#  ('Maurice Lynch', 2),
#  ('Stephen Miles', 1),
#  ('Melanie Frey', 1),
#  ('Eric Munoz', 3),
#  ('Ashley Barajas', 1),
#  ('Melissa Rangel', 3),
#  ('Margaret Martinez', 2),
#  ('Brianna White', 2),
#  ('Monique Serrano MD', 1),
#  ('Beth Nash', 2),
#  ('Jose Small', 1),
#  ('Leslie Elliott', 1),
#  ('Phillip Richards', 1),
#  ('Amber Figueroa', 2),
#  ('Tyrone Zimmerman', 1),
#  ('Briana Gonzalez', 1),
#  ('Amanda Martinez', 2),
#  ('Casey Benitez', 2),
#  ('Bryce Ward', 1),
#  ('Ashley Miller', 1),
#  ('Christopher Miller', 1),
#  ('Kathleen Watson', 1),
#  ('Ashley Clayton', 1),
#  ('Ashley Mcclure', 1),
#  ('Jennifer Warren', 2),
#  ('Mary Smith', 1),
#  ('Jamie Kim', 1),
#  ('Shannon Short', 2),
#  ('David Davis', 3),
#  ('Joshua Little', 2),
#  ('Angela Taylor', 2),
#  ('Tonya Moore', 1),
#  ('Joshua Rhodes', 2),
#  ('Misty Jordan', 2),
#  ('Amy Salinas', 4),
#  ('Sheila Powell', 1),
#  ('Cheryl Charles', 1),
#  ('James Erickson', 2),
#  ('Jason Hicks', 3),
#  ('Samantha Gardner MD', 1),
#  ('Robin Perez DDS', 1),
#  ('Richard Acosta', 1),
#  ('Marcus Phillips', 4),
#  ('David Davis', 1),
#  ('Nancy Flores', 2),
#  ('Steven Michael', 2),
#  ('Matthew Moran', 1),
#  ('Justin Salazar', 1),
#  ('Tammy Miller', 1),
#  ('Theresa Byrd', 3),
#  ('Joshua Gray', 2),
#  ('James Sparks', 2),
#  ('Samantha Richardson', 1),
#  ('Molly Smith', 1),
#  ('Linda Rodriguez', 1),
#  ('Susan Morales', 2),
#  ('Michele Gilmore', 2),
#  ('Dustin Wade', 3),
#  ('Johnathan Davis', 1),
#  ('Jean Fisher', 2),
#  ('Charles Jones', 1),
#  ('Alexander Leblanc', 1),
#  ('Christopher Thompson', 1),
#  ('Corey Hill', 2),
#  ('Ashley Taylor', 2),
#  ('Brandon Robinson', 1),
#  ('James Payne', 2),
#  ('Richard Oconnor', 1),
#  ('Melissa Hartman', 1),
#  ('Alexander Diaz', 3),
#  ('Daniel Lara', 2),
#  ('Charles Watson', 1),
#  ('Matthew Larson', 1),
#  ('Thomas Salinas', 3),
#  ('Harry Mayer', 3),
#  ('Nicole Gonzalez', 3),
#  ('Jordan Lopez', 1),
#  ('Patrick Rogers', 1),
#  ('Gregory Hall', 1),
#  ('Dean Perez', 2),
#  ('Mr. Drew Campbell', 1),
#  ('Ariana Buckley', 3),
#  ('Kim Davis', 2),
#  ('Timothy Williams', 1),
#  ('Gene Atkins', 1),
#  ('Michael Odonnell', 2),
#  ('Thomas Reyes', 2),
#  ('Robert Rodriguez', 1),
#  ('Jessica Leonard', 2),
#  ('Yvonne Nicholson', 2),
#  ('Andrew Sellers', 1),
#  ('Charles Berry', 1),
#  ('Mr. Brandon Rice', 2),
#  ('Christopher Miles', 1),
#  ('Kurt Wong', 1),
#  ('Paige Sharp', 1),
#  ('Matthew Phelps', 1),
#  ('Leslie Jackson', 1),
#  ('Amber Morris', 1),
#  ('Patricia Mccarthy', 2),
#  ('Ernest Dunn', 4),
#  ('Phillip White', 1),
#  ('Jennifer Harris', 1),
#  ('Jerry Williams', 1),
#  ('Jill Hensley', 1),
#  ('Kelsey Jordan', 1),
#  ('Rebecca Gonzales', 1),
#  ('Shannon Jennings', 1),
#  ('Alicia Smith', 2),
#  ('Lisa Brown', 3),
#  ('Joshua Mcclain', 1),
#  ('Ricky Diaz', 2),
#  ('Dana Lamb', 4),
#  ('Thomas Williams', 1),
#  ('Brent Neal', 2),
#  ('Aaron Mitchell', 1),
#  ('Logan Coleman', 2),
#  ('Sandra Lopez', 2),
#  ('Sarah Drake', 3),
#  ('Kendra Reyes', 1),
#  ('Matthew Baker', 1),
#  ('Jennifer Walls', 2),
#  ('Mark Smith', 4),
#  ('Andrew Russell', 1),
#  ('Charles Roth', 2),
#  ('Leonard Reid PhD', 1),
#  ('Susan Cruz', 1),
#  ('John Sanchez', 2),
#  ('Haley Mason', 1),
#  ('Brett Simpson', 2),
#  ('Heather Smith', 2),
#  ('Nicholas Yang', 1),
#  ('Miranda Keller', 1),
#  ('Linda Anderson', 3),
#  ('Mitchell Castillo', 1),
#  ('Kevin Wagner', 2),
#  ('Glenn Flores', 1),
#  ('Jennifer Miller', 1),
#  ('Jennifer Schultz', 1),
#  ('Michael Cortez', 1),
#  ('Brandon Morris', 1),
#  ('Mrs. Amber Blevins', 1),
#  ('Matthew Gardner', 1),
#  ('Steven Green', 1),
#  ('Brandon Miller', 2),
#  ('Joshua Bruce', 1),
#  ('Laura Griffith', 1),
#  ('Lauren Stein', 1),
#  ('Donald Nelson', 1),
#  ('James Lynn', 2),
#  ('Donna Jones', 2),
#  ('Sarah Lam', 1),
#  ('Michelle Stout', 1),
#  ('Jennifer Gonzalez', 2),
#  ('Barbara Coleman', 2),
#  ('Joshua Gonzalez', 2),
#  ('Patricia Flores', 1),
#  ('Natalie Myers', 3),
#  ('Jennifer Harris', 2),
#  ('Jason James', 3),
#  ('Lance Baker', 2),
#  ('Lauren Phillips', 2),
#  ('Linda Gomez', 1),
#  ('Sean Peterson', 1),
#  ('Yvonne Allen', 1),
#  ('Kenneth Hoffman', 1),
#  ('Kristin Valentine', 1),
#  ('Kimberly Crosby', 2),
#  ('Carrie Robbins', 1),
#  ('Richard Clark', 1),
#  ('Gabrielle Perez', 1),
#  ('Donna Castro', 1),
#  ('Daniel Ortiz', 2),
#  ('Carl Smith', 3),
#  ('James Lewis', 2),
#  ('Carla Sims', 2),
#  ('Amanda Thomas', 1),
#  ('Cynthia Shah', 1),
#  ('Jillian Giles', 1),
#  ('Karen Hawkins', 2),
#  ('William Waller', 1),
#  ('Jose Lewis', 2),
#  ('Kevin Banks', 1),
#  ('Jonathan Henderson', 1),
#  ('Misty Rivera', 2),
#  ('Martin Bryant', 1),
#  ('Chloe Mcgee', 2),
#  ('Olivia Adams', 1),
#  ('Stacey Price', 4),
#  ('Jason Smith', 1),
#  ('John Buckley', 2),
#  ('Richard Valentine', 1),
#  ('Rachel Berry', 1),
#  ('Amanda Day', 2),
#  ('Michael Decker', 1),
#  ('Jacob Walker', 1),
#  ('John Padilla', 2),
#  ('Cheryl Walker', 1),
#  ('Jennifer Thompson', 1),
#  ('Karen Evans', 2),
#  ('Eric Castillo', 3),
#  ('Crystal Lamb', 3),
#  ('Linda Russell', 1),
#  ('Richard Thompson', 1),
#  ('Richard Sanchez', 2),
#  ('James Rodriguez', 1),
#  ('Lisa Aguilar', 2),
#  ('Jennifer Kelly', 3),
#  ('Steven Tyler', 1),
#  ('Steven Smith', 1),
#  ('Thomas Scott', 2),
#  ('James Sexton', 1),
#  ('Joshua Johnson', 2),
#  ('Paul Murphy', 2),
#  ('Michael Murray', 2),
#  ('Tiffany Thomas', 1),
#  ('Steve Mckenzie', 1),
#  ('Phillip Jackson', 1),
#  ('Carlos Jacobson', 2),
#  ('Carl Hines', 1),
#  ('Susan Oconnor', 1),
#  ('Richard Carlson', 1),
#  ('Jason Marquez', 1),
#  ('Lori Davis', 1),
#  ('Jeremy Burke', 3),
#  ('James Rodriguez', 2),
#  ('Lauren Peterson', 1),
#  ('Michelle Valenzuela', 1),
#  ('Stefanie Serrano', 2),
#  ('Elizabeth Hamilton', 2),
#  ('Benjamin Lopez', 1),
#  ('April Buchanan', 1),
#  ('Dr. Troy Moran', 1),
#  ('Paula Walters', 1),
#  ('Michelle Willis', 2),
#  ('Christine Fernandez', 1),
#  ('Michael Fernandez', 2),
#  ('Mackenzie Jordan', 1),
#  ('Mrs. Kimberly Byrd DDS', 1),
#  ('Todd Green', 3),
#  ('Kendra Bullock', 3),
#  ('Nicholas Taylor', 1),
#  ('Leslie Williams', 2),
#  ('Whitney Gray', 2),
#  ('Elaine Rice', 1),
#  ('Tamara Hutchinson', 1),
#  ('Michael Snyder', 2),
#  ('Sarah Simmons', 4),
#  ('Alison Bernard', 3),
#  ('Leslie Smith', 2),
#  ('Brian Mcdowell', 2),
#  ('Jeanette Gamble', 2),
#  ('Jordan Tran', 1),
#  ('Michael Gomez', 1),
#  ('Curtis Murphy', 3),
#  ('Jason Duffy', 2),
#  ('Deborah May', 1),
#  ('Mr. Dustin Smith', 2),
#  ('James Thomas', 4),
#  ('Wendy West', 2),
#  ('Jo Lawson', 1),
#  ('Dr. Jeremy Ruiz', 1),
#  ('Amanda Reeves', 2),
#  ('Thomas Kane', 1),
#  ('Miranda Baker', 1),
#  ('Gina Alvarez', 2),
#  ('Stephanie Goodwin', 1),
#  ('James Roman', 1),
#  ('Cheryl West', 1),
#  ('Andrew Roberson', 3),
#  ('Robert Garcia', 2),
#  ('Laura Boyd', 1),
#  ('Sharon Simon', 1),
#  ('Brenda Black', 1),
#  ('Matthew Mitchell', 3),
#  ('Mary Mills', 1),
#  ('Christian Hernandez', 2),
#  ('Melissa Trujillo', 1),
#  ('Toni Smith', 5),
#  ('Christina Delgado', 1),
#  ('Laura Walker', 1),
#  ('Amy Cruz', 2),
#  ('Brittany Russell', 1),
#  ('John Williams', 1),
#  ('Denise Baker', 2),
#  ('Dana Mckenzie', 1),
#  ('Kelly Reynolds', 1),
#  ('Martin Robertson', 1),
#  ('Jennifer Reynolds', 1),
#  ('Sarah Stevenson', 2),
#  ('Kenneth Garcia', 2),
#  ('Stephanie Dixon', 1),
#  ('Julie James', 1),
#  ('David Jackson', 2),
#  ('Holly Riggs DDS', 1),
#  ('Cynthia Colon', 1),
#  ('Gary Dorsey', 1),
#  ('Patrick Rocha', 2),
#  ('Kyle Gomez', 1),
#  ('Michael Moore', 3),
#  ('Melissa Mcdaniel', 1),
#  ('Kathryn Hampton', 2),
#  ('Jennifer Day', 1),
#  ('Jessica Brooks', 3),
#  ('Elizabeth King', 1),
#  ('Melissa Gutierrez', 3),
#  ('Teresa Haley', 1),
#  ('Christopher Ferguson', 1),
#  ('Christine Dean', 1),
#  ('Deborah Sawyer', 1),
#  ('John Good', 1),
#  ('Wendy Cooper', 2),
#  ('Pedro Kelly', 2),
#  ('Kristin Hernandez', 1),
#  ('Veronica Reyes', 1),
#  ('Alexis Phillips', 1),
#  ('Karen Stanton', 1),
#  ('Nicole Moran', 1),
#  ('Amy Lee', 2),
#  ('Jessica Martinez', 1),
#  ('Dawn Thomas', 1),
#  ('Amanda Randolph', 2),
#  ('Megan Moses', 3),
#  ('Joanna Moore', 2),
#  ('Stephanie Everett', 1),
#  ('Gloria Gutierrez', 1),
#  ('Patricia Garza', 1),
#  ('Natalie James', 1),
#  ('Randall Watkins', 1),
#  ('Monica Crane', 2),
#  ('Randy Ruiz', 1),
#  ('James Perez', 1),
#  ('Kimberly Pearson', 1),
#  ('Jacob Bush', 1),
#  ('Sharon Schultz', 2),
#  ('Donald Mann', 2)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-efba87c4d42f> in <module>()
#      27   fp.write(str(result))
#      28   fp.write('\n')
# ---> 29 fp = close('report.txt')
#      30
#      31 #Don't forget to close the file pointer after you have finished!
#
# TypeError: an integer is required (got type str)

# %% [markdown]
# ### Challenge: Write a CSV file
#
# **This challenge isn't for extra marks, it's an opportunity for you to engage in some self guided discovery, only if you feel like it, and only if you have time.**
#
# If you want to challenge yourself, alter the report so that it conforms with the `.csv` file type. There are a number of ways to do this, you can use the `Pandas` module, the `csv` module, or manually.
